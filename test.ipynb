# %%
import sqlite3
from parser.dataclass import *
from parser.db_horse_parser import *
from parser import dataclass
import pandas as pd

pd.set_option('display.max_columns', 500)

# %%
conn = sqlite3.connect("racedata.sqlite3")
cur = conn.cursor()
cur.execute('select * from race limit 1')
[i[0] for i in cur.description]
# Out:
# ['_id',
#  'horse_id',
#  'kishu_id',
#  'chokyoshi_id',
#  'banushi_id',
#  'chakujun',
#  'wakuban',
#  'umaban',
#  'bamei',
#  'sex',
#  'age',
#  'kinryo',
#  'kishu_name',
#  'time',
#  'chakusa',
#  'time_index',
#  'tsuka_1',
#  'tsuka_2',
#  'tsuka_3',
#  'tsuka_4',
#  'nobori',
#  'tansho',
#  'ninki',
#  'bataiju',
#  'zougen',
#  'chokyo_time',
#  'umaya_comment',
#  'bikou',
#  'chokyoshi',
#  'banushi',
#  'shokin']

# %%
class sql_df:
    def __init__(self, db_path: str = "racedata.sqlite3"):
        self.con = sqlite3.connect(db_path)

    def get_race(
        self,
        limit: int = 100000000,
        no_need: list[str]
        | None = [
            "chokyoshi_id",
            "banushi_id",
            "bamei",
            "kishu_name",
            "chokyo_time",
            "umaya_comment",
            "chokyoshi",
            "banushi",
        ],
    ) -> pd.DataFrame:
        return self.get_table("race", limit, no_need)

    def get_race_info(
        self,
        limit: int = 100000000,
        no_need: list[str] | None = ["movie_link"],
    ) -> pd.DataFrame:
        return self.get_table("race_info", limit, no_need)
    
    def get_horse_result(
        self,
        limit: int = 100000000,
        no_need: list[str] | None = ["movie_link","kishu_name","pace","umaya_comment","winner","shokin"],
    ) -> pd.DataFrame:
        return self.get_table("horse_result", limit, no_need)
    
    def get_table(
        self, table_name: str, limit: int, no_need: list[str] | None
    ) -> pd.DataFrame:
        columns = self.get_columns(table_name)
        if no_need is None or no_need == []:
            columns = columns
        else:
            columns = [i for i in columns if i not in no_need]
        query = self.query_statement(table_name, columns, limit)
        return pd.read_sql(sql=query, con=self.con)

    def get_columns(self, table_name: str) -> list[str]:
        df = pd.read_sql(f"select * from {table_name} limit 1", con=self.con)
        return df.columns

    def query_statement(
        self, table: str, columns: list[str], limit: int
    ) -> str:
        return f"select {','.join(columns)} from {table} limit {limit}"

# %%
sd = sql_df()
horse_result = sd.get_horse_result()

# %%
horse_result[horse_result["chakujun"] > 18]
# Out:
#                 _id       race_id kishu_id        date place weather   R  \
# 315312   2008103192  2016G4110107    05528  2016-11-01  フレミン       晴
# 569678   2014103345  2015B6a00207     None  2015-03-28  オースト       晴   7
# 740064   2008103079  2014B6a00707    05454  2014-11-04  オースト       晴
# 823454   2018104934  2022A0a00504    05473  2022-06-18  アスコッ
# 988295   2020102681  2022A0061501    a02cd  2022-06-15  アスコッ
# 1133090  2000190007  2004A8100307    05031  2004-10-03  フランス       晴   7
# 1915271  1990103200  2000A6062002    01026  2000-06-20  イギリス           2
# 2601125  2019105283  2022C8100204    00666  2022-10-02  ロンシャ
# 2957002  1988104493  199105030409    00666  1991-05-26    東京       晴   9
# 3091416  1984105664  198706030810    00246  1987-04-19    中山       晴  10
# 3091588  1986102330  198908050410    00666  1989-11-12    京都       曇  10
# 3092112  1986104156  198905030210    00285  1989-05-21    東京       曇  10
# ...

# %%
con = sqlite3.connect("racedata.sqlite3")
pd.read_sql(f"select * from horse_result limit 1", con=con)
# Out:
#           _id       race_id kishu_id        date place weather  R name  \
# 0  2015100928  202135062902    05490  2021-06-29    盛岡      小雨  2   C2
#
#                                           movie_link  num  wakuban  umaban  \
# 0  https://nar.netkeiba.com/race/movie.html?race_...    7        2       2
#
#    odds  ninki  chakujun kishu_name  kinryo track  distance firm  truck_index  \
# 0   2.5      1         4       山本政聡      54     ダ      1000    良           -5
#
#    time chakusa  time_index  tsuka_1  tsuka_2 tsuka_3 tsuka_4      pace  \
# 0  63.0     1.0          17        1        1    None    None  0.0-37.5
#
#    nobori  bataiju  zougen umaya_comment bikou     winner  shokin
# 0    38.5      462       2          None        アリストレジェンド     2.7
